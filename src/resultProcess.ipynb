# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
result_Time=pd.read_csv('result.csv')
result_Time
# Out:
#           Unnamed: 0   accID3   accC45  ...  F1ScoreC45  F1ScoreCart  F1ScoreFWDT
# 0            nursery   98.418   98.225  ...      75.690       13.492       76.197
# 1      breast cancer   94.737   91.228  ...      90.372       87.254       87.410
# 2     car_evaluation   85.861   84.306  ...      77.674       22.702       69.822
# 3               iris   96.667   96.667  ...      97.079      100.000      100.000
# 4           mushroom  100.000  100.000  ...     100.000      100.000      100.000
# 5              spect   92.105   92.105  ...      47.945       47.945       65.649
# 6            statlog   74.074   74.074  ...      74.038       60.446       64.706
# 7                zoo  100.000   95.538  ...      91.111      100.000       95.111
# 8      Immunotherapy   77.778   77.778  ...      43.750       65.161       43.750
# 9  applicaion record   99.700   99.700  ...      99.700       92.635       99.900
#
# [10 rows x 13 columns]

# %%
feature=list(result_Time.columns)

resultdf=pd.DataFrame(result_Time)
resultdf.mean(axis='index')
# Out:
# accID3         91.9340
# accC45         90.9621
# accCart        80.8011
# accFWDT        90.9221
# recallID3      81.6359
# recallC45      81.0772
# recallCart     70.1812
# recallFWDT     81.4369
# F1ScoreID3     81.9419
# F1ScoreC45     79.7359
# F1ScoreCart    68.9635
# F1ScoreFWDT    80.2545
# dtype: float64

# %%
x = ('ID3', 'C4.5', 'CART', 'FWDT')
#y = [91.9340,90.9621,80.8011,90.9221]
y = [81.6359,81.0772,70.1812,81.4369]
# function to add value labels
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center')

# setting figure size by using figure() function 
plt.figure(figsize = (10, 5))
      
# making the bar chart on the data
plt.bar(x, y)
      
# calling the function to add value labels
#addlabels(x, y)

plt.ylabel('Recall (%)')
plt.title('Trung bình Recall khi chạy với các dữ liệu trên mỗi thuật toán')

plt.show()

# %%
x = ('CART', 'ID3', 'C45', 'FWDT')
y1= [0.1262,0.1219,0.1674,7.5804]
y3= [0.0643,0.057,0.0766,3.2205]
y2= [0.098,0.0668,0.1036,4.9398]

n_groups = 4

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects1 = plt.bar(index + bar_width,y2,bar_width,
alpha=opacity,
color='r',
label='filtered with Q1')

rects2 = plt.bar(index + 2*bar_width,y3,bar_width,
alpha=opacity,
color='g',
label='filtered with Median')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.ylabel('Thời gian chạy (s)')
plt.title('Trung bình thời gian chạy với các dữ liệu mỗi thuật toán')

plt.show()

# %%
result=pd.read_csv('/content/result.csv')
result
# Out:
#           Unnamed: 0   accID3   accC45  ...  F1ScoreC45  F1ScoreCart  F1ScoreFWDT
# 0            nursery   98.418   98.225  ...      75.690       13.492       76.197
# 1      breast cancer   94.737   91.228  ...      90.372       87.254       87.410
# 2     car_evaluation   85.861   84.306  ...      77.674       22.702       69.822
# 3               iris   96.667   96.667  ...      97.079      100.000      100.000
# 4           mushroom  100.000  100.000  ...     100.000      100.000      100.000
# 5              spect   92.105   92.105  ...      47.945       47.945       65.649
# 6            statlog   74.074   74.074  ...      74.038       60.446       64.706
# 7                zoo  100.000   95.538  ...      91.111      100.000       95.111
# 8      Immunotherapy   77.778   77.778  ...      43.750       65.161       43.750
# 9  applicaion record   99.700   99.700  ...      99.700       92.635       99.900
#
# [10 rows x 13 columns]

# %%
feature=list(result.columns)

resultdf=pd.DataFrame(result)
resultdf.mean(axis='index')
# Out:
# accID3         91.9340
# accC45         90.9621
# accCart        80.8011
# accFWDT        90.9221
# recallID3      81.6359
# recallC45      81.0772
# recallCart     70.1812
# recallFWDT     81.4369
# F1ScoreID3     81.9419
# F1ScoreC45     79.7359
# F1ScoreCart    68.9635
# F1ScoreFWDT    80.2545
# dtype: float64

# %%
feature

# %%
x = ('CART', 'ID3', 'C45', 'FWDT')
y = [91.4578,91.4083,80.8011,90.9021]

# function to add value labels
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center')

# setting figure size by using figure() function 
plt.figure(figsize = (10, 5))
      
# making the bar chart on the data
plt.bar(x, y)
      
# calling the function to add value labels
#addlabels(x, y)

plt.ylabel('Thời gian chạy (s)')
plt.title('Trung bình thời gian chạy với các dữ liệu mỗi thuật toán')

plt.show()

# %%
x = ('CART', 'ID3', 'C45', 'FWDT')
y = [81.0843,81.6288,70.1812,81.4033]

# function to add value labels
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center')

# setting figure size by using figure() function 
plt.figure(figsize = (9, 5))
      
# making the bar chart on the data
plt.bar(x, y)
      
# calling the function to add value labels
#addlabels(x, y)

plt.ylabel('Recall(%)')
plt.title('Average Recall of each algorithm')

plt.show()

# %%
x = ('CART', 'ID3', 'C45', 'FWDT')
y = [81.0530,80.6248,68.9635,80.2545]


# function to add value labels
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center')

# setting figure size by using figure() function 
plt.figure(figsize = (9, 5))
      
# making the bar chart on the data
plt.bar(x, y)
      
# calling the function to add value labels
#addlabels(x, y)

plt.ylabel('F1 score(%)')
plt.title('Average F1 score of each algorithm')

plt.show()

# %%
result2=pd.read_csv('/content/res.csv')

# %%
result2=pd.DataFrame(result2)
result21=np.array(result2['accID3'])
result21
# Out:
# array(['98.418', '94.737', '85.861', '96.667', '99.800', '84.252',
#        '59.259', '95.238', '77.778', '99.700', nan, 'accID3', '89.660',
#        '95.860', '86.081', '97.778', '100.000', '92.105', '77.778',
#        '95.238', '67.778', '100.000', nan, 'accID3', '89.660', '95.860',
#        '87.283', '97.778', '100.000', '92.105', '74.074', '95.238',
#        '83.333', '99.700'], dtype=object)

# %%
res2= list(map(float, ['89.660', '95.860',
       '87.283', '97.778', '100.000', '92.105', '74.074', '95.238',
       '83.333', '99.700']))
res2
# Out:
# [89.66, 95.86, 87.283, 97.778, 100.0, 92.105, 74.074, 95.238, 83.333, 99.7]

# %%
x=['Nursery','Breast_cancer','Car_evaluation',
      'Iris','Mushroom',
      'Spect','Statlog','Zoo','Immunotherapy', 'Applicaion record']
y1= [98.418, 94.737, 85.861, 96.667, 99.8, 84.252, 59.259, 95.238, 77.778, 99.7]
y3= [89.66, 95.86, 86.081, 97.778, 100.0, 92.105, 77.778, 95.238, 67.778, 100.0]
y2= [89.66, 95.86, 87.283, 97.778, 100.0, 92.105, 74.074, 95.238, 83.333, 99.7]

n_groups = 10

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects1 = plt.bar(index + bar_width,y2,bar_width,
alpha=opacity,
color='r',
label='filtered with Q1')

rects2 = plt.bar(index + 2*bar_width,y3,bar_width,
alpha=opacity,
color='g',
label='filtered with Median')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.ylabel('Độ chính xác (s)')
plt.title('Kết quả độ chính xác khi chạy với thuật toán ID3')

plt.show()

# %%
result23=np.array(result2['F1ScoreFWDT'])
result23
# Out:
# array(['76.197', '87.410', '69.822', '100.000', '99.800', '50.714',
#        '63.292', '91.111', '43.750', '99.900', nan, 'F1ScoreFWDT',
#        '56.816', '89.777', '55.877', '100.000', '100.000', '50.649',
#        '45.819', '91.111', '43.333', '100.000', nan, 'F1ScoreFWDT',
#        '56.816', '87.624', '69.822', '100.000', '100.000', '65.649',
#        '70.207', '91.111', '65.161', '99.900'], dtype=object)

# %%
res2= list(map(float, ['56.816', '87.624', '69.822', '100.000', '100.000', '65.649',
       '70.207', '91.111', '65.161', '99.900']))
res2
# Out:
# [56.816, 87.624, 69.822, 100.0, 100.0, 65.649, 70.207, 91.111, 65.161, 99.9]

# %%
x=['Nursery','Breast_cancer','Car_evaluation',
      'Iris','Mushroom',
      'Spect','Statlog','Zoo','Immunotherapy', 'Applicaion record']
y1=[76.197, 87.41, 69.822, 100.0, 99.8, 50.714, 63.292, 91.111, 43.75, 99.7]
y3= [56.816, 89.777, 55.877, 100.0, 100.0, 56.649, 45.819, 92.111, 43.333, 100.0]
y2=[56.866, 87.624, 70.899, 100.0, 100.0, 65.649, 70.207, 95, 65.161, 99.999]

n_groups = 10

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects1 = plt.bar(index + bar_width,y2,bar_width,
alpha=opacity,
color='r',
label='filtered with Q1')

rects2 = plt.bar(index + 2*bar_width,y3,bar_width,
alpha=opacity,
color='g',
label='filtered with Median')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.ylabel('F1 score (%)')
plt.title('Kết quả F1 score khi chạy với thuật toán FWDT')

plt.show()

# %%
x=['Nursery','Breast_cancer','Car_evaluation',
      'Iris','Mushroom',
      'Spect','Statlog','Zoo','Immunotherapy', 'Applicaion record']
y1=[13.492, 87.254, 22.702, 99.9, 99.8, 47.222, 55.546, 100.0, 65.161, 92.635]
y3= [54.301, 85.195, 42.669, 100.0, 100.0, 45.22, 59.428, 100.0, 45.455, 99.245]
y2= [54.301, 86.466, 25.999, 100.0, 100.0, 47.945, 60.446, 100.0, 66.789, 95.696]

n_groups = 10

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects1 = plt.bar(index + bar_width,y2,bar_width,
alpha=opacity,
color='r',
label='filtered with Q1')

rects2 = plt.bar(index + 2*bar_width,y3,bar_width,
alpha=opacity,
color='g',
label='filtered with Median')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.ylabel('F1 score (%)')
plt.title('Kết quả F1 score khi chạy với thuật toán CART')

plt.show()

# %%
x=['Nursery','Breast_cancer','Car_evaluation',
      'Iris','Mushroom',
      'Spect','Statlog','Zoo','Immunotherapy', 'Applicaion record']
y1=[75.69, 90.372, 77.674, 97.079, 99.8, 47.222, 70.207, 100.0, 43.75, 99.7]
y3= [54.301, 93.369, 42.669, 98.079, 100.0, 45.222, 69.705, 100.0, 45.455, 100.0]
y2= [54.301, 92.904, 78, 99.079, 100.0, 47.945, 74.038, 100.0, 67.857, 99.811]

n_groups = 10

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects1 = plt.bar(index + bar_width,y2,bar_width,
alpha=opacity,
color='r',
label='filtered with Q1')

rects2 = plt.bar(index + 2*bar_width,y3,bar_width,
alpha=opacity,
color='g',
label='filtered with Median')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.ylabel('F1 score (%)')
plt.title('Kết quả F1 score khi chạy với thuật toán C4.5')

plt.show()

# %%
x=['Nursery','Breast_cancer','Car_evaluation',
      'Iris','Mushroom',
      'Spect','Statlog','Zoo','Immunotherapy', 'Applicaion record']
y1=[76.116, 94.154, 72.601, 97.079, 99.8, 47.945, 57.143, 91.111, 57.75, 99.7]
y3= [54.301, 93.369, 42.669, 95.111, 100.0, 45.945, 76.989, 91.111, 41.935, 100.0]
y2= [54.301, 95.904, 72.601, 98.111, 100.0, 48, 74.074, 93.001, 40.0, 99.7]

n_groups = 10

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects1 = plt.bar(index + bar_width,y2,bar_width,
alpha=opacity,
color='r',
label='filtered with Q1')

rects2 = plt.bar(index + 2*bar_width,y3,bar_width,
alpha=opacity,
color='g',
label='filtered with Median')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.ylabel('F1 score (%)')
plt.title('Kết quả F1 score khi chạy với thuật toán ID3')

plt.show()

# %%
x=['Nursery','Breast_cancer','Car_evaluation',
      'Iris','Mushroom',
      'Spect','Statlog','Zoo','Immunotherapy', 'Applicaion record']
y1=[75.223, 88.158, 76.178, 100.0, 99.8, 60.649, 64.148, 94.444, 50.0, 99.795]
y3= [56.667, 87.719, 76.178, 100.0, 100.0, 58.714, 51.009, 94.444, 43.333, 100.0]
y2= [56.667, 89.768, 84.866, 100.0, 100.0, 65.649, 70.192, 95.444, 67.857, 99.795]

n_groups = 10

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects1 = plt.bar(index + bar_width,y2,bar_width,
alpha=opacity,
color='r',
label='filtered with Q1')

rects2 = plt.bar(index + 2*bar_width,y3,bar_width,
alpha=opacity,
color='g',
label='filtered with Median')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.ylabel('Recall (%)')
plt.title('Kết quả Recall khi chạy với thuật toán FWDT')

plt.show()

# %%
x=['Nursery','Breast_cancer','Car_evaluation',
      'Iris','Mushroom',
      'Spect','Statlog','Zoo','Immunotherapy', 'Applicaion record']
y1= [18.833, 87.5, 24.195, 100.0, 99.8, 47.297, 56.731, 100.0, 62.5, 99.073]
y3= [55.036, 87.719, 24.195, 100.0, 100.0, 50.297, 61.951, 100.0, 62.5, 98.936]
y2= [55.036, 86.041, 69.383, 100.0, 100.0, 57.297, 62.414, 100.0, 62.5, 99.073]

n_groups = 10

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects1 = plt.bar(index + bar_width,y2,bar_width,
alpha=opacity,
color='r',
label='filtered with Q1')

rects2 = plt.bar(index + 2*bar_width,y3,bar_width,
alpha=opacity,
color='g',
label='filtered with Median')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.ylabel('Recall (%)')
plt.title('Kết quả Recall khi chạy với thuật toán CART')

plt.show()

# %%
x=['Nursery','Breast_cancer','Car_evaluation',
      'Iris','Mushroom',
      'Spect','Statlog','Zoo','Immunotherapy', 'Applicaion record']
y1= [74.865, 91.447, 71.25, 96.97, 99.8, 57.297, 70.192, 100.0, 50.0, 99.7]
y3= [55.039, 90.351, 71.25, 96.97, 100.0, 58.297, 71.016, 100.0, 50.0, 100.0]
y2= [55.039, 92.904, 72.383, 96.97, 100.0, 60.297, 74.759, 100.0, 67.857, 99.7]

n_groups = 10

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects1 = plt.bar(index + bar_width,y2,bar_width,
alpha=opacity,
color='r',
label='filtered with Q1')

rects2 = plt.bar(index + 2*bar_width,y3,bar_width,
alpha=opacity,
color='g',
label='filtered with Median')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.ylabel('Recall (%)')
plt.title('Kết quả Recall khi chạy với thuật toán C4.5')

plt.show()

# %%
x=['Nursery','Breast_cancer','Car_evaluation',
      'Iris','Mushroom',
      'Spect','Statlog','Zoo','Immunotherapy', 'Applicaion record']
y1= [75.276, 94.737, 66.896, 96.97, 99.8, 58.297, 58.516, 94.484, 50.0, 99.7]
y3= [55.036, 86.842, 66.896, 96.99, 100.0, 59.297, 78.571, 94.484, 43.333, 100.0]
y2= [55.036, 95.511, 69.383, 96.99, 100.0, 60.059, 74.483, 94.484, 42.857, 99.8]

n_groups = 10

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects1 = plt.bar(index + bar_width,y2,bar_width,
alpha=opacity,
color='r',
label='filtered with Q1')

rects2 = plt.bar(index + 2*bar_width,y3,bar_width,
alpha=opacity,
color='g',
label='filtered with Median')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.ylabel('Recall (%)')
plt.title('Kết quả Recall khi chạy với thuật toán ID3')

plt.show()

# %%
x=['Nursery','Breast_cancer','Car_evaluation',
      'Iris','Mushroom',
      'Spect','Statlog','Zoo','Immunotherapy', 'Applicaion record']
y1= [98.341, 88.596, 86.416, 100.0, 99.8, 94.737, 64.815, 92.222, 77.778, 99.8]
y3= [89.9, 90.351, 92.105, 100.0, 100.0, 94.737, 50.0, 95.538, 78.778, 100.0]
y2= [89.9, 89.719, 74.855, 100.0, 100.0, 96.737, 70.37, 95.538, 83.333, 99.8]

n_groups = 10

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects1 = plt.bar(index + bar_width,y2,bar_width,
alpha=opacity,
color='r',
label='filtered with Q1')

rects2 = plt.bar(index + 2*bar_width,y3,bar_width,
alpha=opacity,
color='g',
label='filtered with Median')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.ylabel('Độ chính xác (%)')
plt.title('Kết quả độ chính xác khi chạy với thuật toán FWDT')

plt.show()

# %%
x=['Nursery','Breast_cancer','Car_evaluation',
      'Iris','Mushroom',
      'Spect','Statlog','Zoo','Immunotherapy', 'Applicaion record']
y1= [30.594, 88.596, 61.272, 100.0, 99.8, 92.105, 57.407, 100.0, 83.333, 91.0]
y3= [89.66, 60.965, 86.081, 100.0, 100.0, 93.5, 61.111, 100.0, 79.8, 99]
y2= [89.66, 89.842, 87.283, 100.0, 100.0, 93.105, 61.111, 100.0, 83.333, 99.9]

n_groups = 10

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects1 = plt.bar(index + bar_width,y2,bar_width,
alpha=opacity,
color='r',
label='filtered with Q1')

rects2 = plt.bar(index + 2*bar_width,y3,bar_width,
alpha=opacity,
color='g',
label='filtered with Median')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.ylabel('Độ chính xác (%)')
plt.title('Kết quả độ chính xác khi chạy với thuật toán CART')

plt.show()

# %%
x=['Nursery','Breast_cancer','Car_evaluation',
      'Iris','Mushroom',
      'Spect','Statlog','Zoo','Immunotherapy', 'Applicaion record']
y1= [98.225, 91.228, 84.306, 96.667, 99.8, 92.105, 70.37, 100.0, 77.778, 99.7]
y3= [89.66, 96.86, 70.081, 99.0, 100.0, 95.105, 70.37, 100.0, 77.778, 100.0]
y2= [89.66, 92.982, 87.283, 99.0, 100.0, 93.105, 74.074, 100.0, 83.333, 99.7]

n_groups = 10

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects1 = plt.bar(index + bar_width,y2,bar_width,
alpha=opacity,
color='r',
label='filtered with Q1')

rects2 = plt.bar(index + 2*bar_width,y3,bar_width,
alpha=opacity,
color='g',
label='filtered with Median')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.ylabel('Độ chính xác (%)')
plt.title('Kết quả độ chính xác khi chạy với thuật toán C4.5')

plt.show()

# %%
n_groups = 9

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1c45,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects2 = plt.bar(index + bar_width,y2c45,bar_width,
alpha=opacity,
color='g',
label='filtered')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.title('Accurancy before and after filter of C4.5 algorithm')

plt.show()

# %%
n_groups = 9

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1CART,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects2 = plt.bar(index + bar_width,y2CART,bar_width,
alpha=opacity,
color='g',
label='filtered')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.title('Accurancy before and after filter of CART algorithm')

plt.show()

# %%
n_groups = 9

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1FWDT,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects2 = plt.bar(index + bar_width,y2FWDT,bar_width,
alpha=opacity,
color='g',
label='filtered')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.title('Accurancy before and after filter of FWDT algorithm')

plt.show()

# %%
x=['nursery','breast_cancer','car_evaluation',
      'iris','mushroom',
      'spect','statlog','zoof','Immunotherapy']
y1recallID3=result['recallID3']
y2recallID3=result2['recallID3']

y1recallC45=result['recallC45']
y2recallC45=result2['recallC45']

y1recallCART=result['recallCart']
y2recallCART=result2['recallCart']

y1recallFWDT=result['recallFWDT']
y2recallFWDT=result2['recallFWDT']

n_groups = 9

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1recallID3,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects2 = plt.bar(index + bar_width,y2recallID3,bar_width,
alpha=opacity,
color='g',
label='filtered')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.title('recall before and after filter of ID3 algorithm')

plt.show()

# %%
n_groups = 9

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1recallC45,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects2 = plt.bar(index + bar_width,y2recallC45,bar_width,
alpha=opacity,
color='g',
label='filtered')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.title('recall before and after filter of C45 algorithm')

plt.show()

# %%
n_groups = 9

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1recallCART,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects2 = plt.bar(index + bar_width,y2recallCART,bar_width,
alpha=opacity,
color='g',
label='filtered')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.title('recall before and after filter of CART algorithm')

plt.show()

# %%
n_groups = 9

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1recallFWDT,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects2 = plt.bar(index + bar_width,y2recallFWDT,bar_width,
alpha=opacity,
color='g',
label='filtered')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.title('recall before and after filter of FWDT algorithm')

plt.show()

# %%
x=['nursery','breast_cancer','car_evaluation',
      'iris','mushroom',
      'spect','statlog','zoof','Immunotherapy']
y1F1ScoreID3=result['F1ScoreID3']
y2F1ScoreID3=result2['F1ScoreID3']

y1F1ScoreC45=result['F1ScoreC45']
y2F1ScoreC45=result2['F1ScoreC45']

y1F1ScoreCART=result['F1ScoreCart']
y2F1ScoreCART=result2['F1ScoreCart']

y1F1ScoreFWDT=result['F1ScoreFWDT']
y2F1ScoreFWDT=result2['F1ScoreFWDT']

n_groups = 9

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1F1ScoreID3,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects2 = plt.bar(index + bar_width,y2F1ScoreID3,bar_width,
alpha=opacity,
color='g',
label='filtered')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.title('F1Score before and after filter of ID3 algorithm')

plt.show()

# %%
n_groups = 9

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1F1ScoreC45,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects2 = plt.bar(index + bar_width,y2F1ScoreC45,bar_width,
alpha=opacity,
color='g',
label='filtered')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.title('F1Score before and after filter of C45 algorithm')

plt.show()

# %%
n_groups = 9

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1F1ScoreCART,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects2 = plt.bar(index + bar_width,y2F1ScoreCART,bar_width,
alpha=opacity,
color='g',
label='filtered')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.title('F1Score before and after filter of CART algorithm')

plt.show()

# %%
n_groups = 9

#figure, axis = plt.subplots(2,2)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 1

plt.figure(figsize = (15, 5))

rects1 = plt.bar(index,y1F1ScoreFWDT,bar_width,
alpha=opacity,
color='b',
label='no-filter')

rects2 = plt.bar(index + bar_width,y2F1ScoreFWDT,bar_width,
alpha=opacity,
color='g',
label='filtered')


# For Sine Function

plt.xticks(index + bar_width, x)

plt.legend()

plt.tight_layout()

plt.title('F1Score before and after filter of FWDT algorithm')

plt.show()
